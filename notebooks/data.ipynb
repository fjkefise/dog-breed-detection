# %%
import os
import json
import glob
from concurrent.futures import ThreadPoolExecutor, as_completed
from inference_sdk import InferenceHTTPClient

client = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="4YTsQ9U6cmsFvVyPZuet"
)

def get_maltese_images(base_dir="."):
    image_paths = []
    for split in ["train", "valid", "test"]:
        folder = os.path.join(base_dir, split, "Pekinese")
        if os.path.exists(folder):
            for ext in ["*.jpg", "*.jpeg", "*.png", "*.bmp"]:
                image_paths.extend(glob.glob(os.path.join(folder, ext)))
    return image_paths

def process_single_image(img_path):
    try:
        result = client.run_workflow(
            workspace_name="classification-qqjwe",
            workflow_id="find-dogs-6",
            images={"image": img_path},
            use_cache=True
        )
        return {"path": img_path, "result": result, "error": None}
    except Exception as e:
        return {"path": img_path, "result": None, "error": str(e)}

def batch_process_images(image_paths, batch_size=20, output_file="Pekinese.json"):
    all_results = {}
    
    total_batches = (len(image_paths) + batch_size - 1) // batch_size
    
    for i in range(0, len(image_paths), batch_size):
        batch = image_paths[i:i + batch_size]
        batch_num = i // batch_size + 1
        print(f"Обрабатываю batch {batch_num}/{total_batches}")
        
        with ThreadPoolExecutor(max_workers=10) as executor:
            future_to_image = {executor.submit(process_single_image, img): img for img in batch}
            
            for future in as_completed(future_to_image):
                result = future.result()
                all_results[result["path"]] = {
                    "result": result["result"],
                    "error": result["error"]
                }
                
                if result["error"]:
                    print(f"Ошибка: {os.path.basename(result['path'])} - {result['error']}")
                else:
                    print(f"Успешно: {os.path.basename(result['path'])}")
    
    with open(output_file, 'w') as f:
        json.dump(all_results, f, indent=2, default=str)
    
    return all_results

if __name__ == "__main__":
    maltese_images = get_maltese_images()
    print(f"Найдено изображений Pekinese: {len(maltese_images)}")
    
    if maltese_images:
        results = batch_process_images(maltese_images, batch_size=100)
        print(f"\nОбработано {len(results)} изображений")
# Out:
# Найдено изображений Pekinese: 319
# Обрабатываю batch 1/4
# Успешно: Pekinese_10932_jpg.rf.01a368287347d86148c4e63d3aead5f3.jpg
# Успешно: Pekinese_1020_jpg.rf.f104f989a055627643dfeed3f944ef76.jpg
# Успешно: Pekinese_7817_jpg.rf.2c41b222b27e81d9a4086cdb7b60ef12.jpg
# Успешно: Pekinese_19690_jpg.rf.2a8a1832eea37afa8b2abf64daefff1a.jpg
# Успешно: Pekinese_3174_jpg.rf.a15ec6309995f217ef4f662400c46476.jpg
# Успешно: Pekinese_10689_jpg.rf.520283127e512d0591ee34b48266850b.jpg
# Успешно: Pekinese_5053_jpg.rf.3339be3261c239aa2ce31de9ceeac41c.jpg
# Успешно: Pekinese_17291_jpg.rf.6650d55d54755b545157de02e50e8684.jpg
# Успешно: Pekinese_6956_jpg.rf.b04f137d6e012bb7ecd459eca447173e.jpg
# Успешно: Pekinese_1877_jpg.rf.4d76c33dddbe33ef188cf34a94277053.jpg
# Успешно: Pekinese_937_jpg.rf.87fd7aebc53ec185dd4a2e005f9bead3.jpg
# Успешно: Pekinese_2287_jpg.rf.549acc8172f1f12b4ddb81bb8706b28c.jpg
# Успешно: Pekinese_5087_jpg.rf.b6578d9ff8eaf25999a6456670ff28fc.jpg
# Успешно: Pekinese_1020_jpg.rf.bc4aa0210430383d58c84222a4e6e27f.jpg
# Успешно: Pekinese_2073_jpg.rf.2efbc87fa2b2cdf33d4ec4325e61dc67.jpg
# Успешно: Pekinese_9316_jpg.rf.fd34caa275ca83a8b00b43d2719425c5.jpg
# Успешно: Pekinese_3174_jpg.rf.0c4065b91124bd7d81728a75dfbf598e.jpg
# Успешно: Pekinese_9151_jpg.rf.3fb3b5a5fe1e6608c2d0505ca322bcc4.jpg
# Успешно: Pekinese_3996_jpg.rf.b21281f1dbcd59d7f7aaf11ddc0577ba.jpg
# Успешно: Pekinese_1591_jpg.rf.e528d2251a8d26c14b6a923d78398a3f.jpg
# Успешно: Pekinese_6467_jpg.rf.9933e7f28110b3140aeb4da17364bdfb.jpg
# Успешно: Pekinese_7068_jpg.rf.66ecf2cf3720e73f06bb647bff54d234.jpg
# Успешно: Pekinese_6620_jpg.rf.58db64e49d11d35d3482bd9ef00f21c3.jpg
# Успешно: Pekinese_12321_jpg.rf.e61e2050f6d06c726884f4b475e13210.jpg
# Успешно: Pekinese_11511_jpg.rf.cf76a35ae69d413872a4cdba861baa2f.jpg
# Успешно: Pekinese_6620_jpg.rf.ccbf02a7e5fab0a3a4a5cee624bf90fa.jpg
# Успешно: Pekinese_10932_jpg.rf.9470714a598215e6825942bcf828922d.jpg
# Успешно: Pekinese_13647_jpg.rf.b8667c84f9701027a5223fac60541c24.jpg
# Успешно: Pekinese_15375_jpg.rf.1a2d337dee10163ce54b2f60368ff500.jpg
# Успешно: Pekinese_9756_jpg.rf.e462d8dc992090852d03cb033f337465.jpg
# Успешно: Pekinese_5766_jpg.rf.70763476a75e2f4770f33ecd6b99e3c7.jpg
# Успешно: Pekinese_1451_jpg.rf.2cdc0c7b57cfbc7d05bf8f88ba389c62.jpg
# Успешно: Pekinese_6096_jpg.rf.f843720b679ca5f9fe62dc85e0bfbb41.jpg
# Успешно: Pekinese_869_jpg.rf.2942125e6b4ef158aaa2c1377b4564b3.jpg
# Успешно: Pekinese_15220_jpg.rf.7de7825db3674a30a4d0ad488a7b0ad4.jpg
# Успешно: Pekinese_17103_jpg.rf.2666d97c465f1b19e9fcecc0a4ce85b2.jpg
# Успешно: Pekinese_9316_jpg.rf.c2bedd9d4329e1a04ba6d6ad0934c962.jpg
# Успешно: Pekinese_23100_jpg.rf.964c142e0bc700e41053eb282749639e.jpg
# Успешно: Pekinese_14532_jpg.rf.d4c30902c863e47656e26ad22656ef7b.jpg
# Успешно: Pekinese_15871_jpg.rf.bab2c2abd10e0e3be0091469f0c094a6.jpg
# Успешно: Pekinese_4129_jpg.rf.d08a39c75793014e1cdc1441ffbfbb58.jpg
# Успешно: Pekinese_499_jpg.rf.be3fd44be4c5c43701035f6513d82bc4.jpg
# Успешно: Pekinese_3174_jpg.rf.e6d832f780a38e94feb05eb6ec01b91b.jpg
# Успешно: Pekinese_6180_jpg.rf.58c5d134faf697767cc80b585c5412ae.jpg
# Успешно: Pekinese_22412_jpg.rf.28beab8ec56d36447aaee9e64b5c5e39.jpg
# Успешно: Pekinese_6180_jpg.rf.8452a6e95cf037a3d1372d744e4d3b26.jpg
# Успешно: Pekinese_17291_jpg.rf.5350ba2a200c781dc6997c48f09e7208.jpg
# Успешно: Pekinese_10932_jpg.rf.d12729f698e0ca54d43edeb35bfbd28b.jpg
# Успешно: Pekinese_17983_jpg.rf.da79e3f71d26c278c5392ec29bedcf42.jpg
# Успешно: Pekinese_10951_jpg.rf.896e5cf068e7642a2260203f5694ce34.jpg
# Успешно: Pekinese_5590_jpg.rf.dd34425c018d6e485763bcec91a5706a.jpg
# Успешно: Pekinese_11322_jpg.rf.d3e1b696b5e818f07cf8dd300b70b14f.jpg
# Успешно: Pekinese_23100_jpg.rf.564a53290263c0812d743864b684a181.jpg
# Успешно: Pekinese_347_jpg.rf.c64645c51838600e8110c4c68198c1a5.jpg
# Успешно: Pekinese_1591_jpg.rf.78d83427309a87f890472614371d917c.jpg
# Успешно: Pekinese_380_jpg.rf.e7214210da12374b0679c77783201e61.jpg
# Успешно: Pekinese_5522_jpg.rf.87777a4a752859fb9329ad132583b414.jpg
# Успешно: Pekinese_6467_jpg.rf.7720754b701230d22d0c2d38ea43b3ec.jpg
# Успешно: Pekinese_22412_jpg.rf.fd5e04440fa4d0b9fb0e9324beb7ac0a.jpg
# Успешно: Pekinese_6333_jpg.rf.37f0ba4bd33ad91bedc74dd6f119aa46.jpg
# Успешно: Pekinese_8204_jpg.rf.38460d85328673ca8d30c66d6133d4ac.jpg
# Успешно: Pekinese_2073_jpg.rf.2344003b706f8cbec60c3761cfd0c9f5.jpg
# Успешно: Pekinese_11684_jpg.rf.5cfabfbc3fcd3096d68c3834c974ac36.jpg
# Успешно: Pekinese_12125_jpg.rf.8be6d7bf4f35ed4206762fdb4944e929.jpg
# Успешно: Pekinese_4456_jpg.rf.73a846decc727baa8e1f7190e4c51b23.jpg
# Успешно: Pekinese_3149_jpg.rf.8084d4d32fcf46f96c0cbb118e021621.jpg
# Успешно: Pekinese_6333_jpg.rf.4136d5d0cb428db3dd56cfe3feed33cd.jpg
# Успешно: Pekinese_2368_jpg.rf.d21715d181062daa98a5154aa1dc1be0.jpg
# Успешно: Pekinese_5053_jpg.rf.a9ae7eb98dc7bc1eed82b44f7f36370b.jpg
# Успешно: Pekinese_8127_jpg.rf.d4872c441f7fcb5b47befa1e5aae47fe.jpg
# Успешно: Pekinese_2287_jpg.rf.55d54546187dacd8a249445995d0f2e3.jpg
# Успешно: Pekinese_14359_jpg.rf.8e351014d4732afbf32f756b145ba566.jpg
# Успешно: Pekinese_11984_jpg.rf.b75e610fb86e638d26fe2f2ff1962f27.jpg
# Успешно: Pekinese_207_jpg.rf.1dc313997484786d86385915aa7dfc74.jpg
# Успешно: Pekinese_23100_jpg.rf.777890a785aa27287d5e2c3eab1c91ae.jpg
# Успешно: Pekinese_5087_jpg.rf.9377d3ae5e7682fdea8ed967d384a797.jpg
# Успешно: Pekinese_14307_jpg.rf.1761553132bac48d64a4a43e759dc4a1.jpg
# Успешно: Pekinese_10721_jpg.rf.c1ed62438ddc198b751bc2c285e7ba63.jpg
# Успешно: Pekinese_869_jpg.rf.3002a86bdc5408d67fc6d5b88f9e94ac.jpg
# Успешно: Pekinese_17103_jpg.rf.a6d012ae696ed9a5dd82ec0a4a6b0459.jpg
# Успешно: Pekinese_937_jpg.rf.04b216176c2846d42f20197d20fd3e38.jpg
# Успешно: Pekinese_2209_jpg.rf.57d166963153dab2e5bffbe296511fb9.jpg
# Успешно: Pekinese_4412_jpg.rf.d0edd98d61e609e1f6281d0c6c1f6097.jpg
# Успешно: Pekinese_17686_jpg.rf.b6370b69be7b38add28a41d5013d774d.jpg
# Успешно: Pekinese_11679_jpg.rf.06cab01fb36c4b4a248a8a62c3b86fa0.jpg
# Успешно: Pekinese_5590_jpg.rf.71d4628bed2a381a474c03612704b185.jpg
# Успешно: Pekinese_5106_jpg.rf.1d58bb7619e08d74aaad09fbe6ee5be7.jpg
# Успешно: Pekinese_6956_jpg.rf.af24126148141c3f55ac3c76d0cb120b.jpg
# Успешно: Pekinese_7068_jpg.rf.be16d3a3f949cfe85d51d0ae5eb3490b.jpg
# Успешно: Pekinese_4456_jpg.rf.199cf388f02a83f01b2588ce5e2c4620.jpg
# Успешно: Pekinese_15220_jpg.rf.40f62e322401fa2a738386d37430c1f8.jpg
# Успешно: Pekinese_21103_jpg.rf.05211a39d10629b83827c616b514e69c.jpg
# Успешно: Pekinese_5590_jpg.rf.d8c4147147ffc1a8a82c1bec64774742.jpg
# Успешно: Pekinese_13897_jpg.rf.2b97f479ee796ec1cf38ebc54c9b6cbc.jpg
# Успешно: Pekinese_8826_jpg.rf.d0dd1e552fe3a3148ce7d0d08e04362d.jpg
# Успешно: Pekinese_14532_jpg.rf.63734fba8716c75c471e3de83a3c231d.jpg
# Успешно: Pekinese_2287_jpg.rf.39c41bca08f167afcf704089f5d1bd5d.jpg
# Успешно: Pekinese_11322_jpg.rf.b111cad9ca46f35c6b375e683fdede58.jpg
# Успешно: Pekinese_21103_jpg.rf.54701408698d792a0b666003bd6e2424.jpg
# Успешно: Pekinese_5053_jpg.rf.95e46ef79ce9748dbdee8b5efd932863.jpg
# Обрабатываю batch 2/4
# Успешно: Pekinese_20360_jpg.rf.7212dbaa404d36f5d8a5ce0726da5c7a.jpg
# Успешно: Pekinese_5522_jpg.rf.38d60cbcc6eb527ec7d2122e72aa9538.jpg
# Успешно: Pekinese_8826_jpg.rf.eb6d1ecc32bb692a220dcd5ca65671c6.jpg
# Успешно: Pekinese_499_jpg.rf.bd05bb213ac2efac93a724460c7fa308.jpg
# Успешно: Pekinese_2368_jpg.rf.4c0e0183c8936adcec245b571b269315.jpg
# Успешно: Pekinese_14359_jpg.rf.09ce6ae668802c37dfede2cee616b7f9.jpg
# Успешно: Pekinese_12321_jpg.rf.df6207d30b1677116d59d0f5aad31a10.jpg
# Успешно: Pekinese_8726_jpg.rf.839547d0a248ff85905a797dc1818dd7.jpg
# Успешно: Pekinese_2935_jpg.rf.15842a78e63eabe98cd9c99bcd211f9e.jpg
# Успешно: Pekinese_13647_jpg.rf.4b374ba8fbc01ec6af0d8217de270072.jpg
# Успешно: Pekinese_3149_jpg.rf.dc14bef71e025758aeef0dde5fa89af2.jpg
# Успешно: Pekinese_10689_jpg.rf.2a60581771cff58225c99e3925e1a92c.jpg
# Успешно: Pekinese_1451_jpg.rf.a8588f40e84620781948a491d2d8f0b9.jpg
# Успешно: Pekinese_11511_jpg.rf.9c487fcf9e6186eb11115413454ba32d.jpg
# Успешно: Pekinese_14532_jpg.rf.277ea3fb0da92e3854eb73e237948c3a.jpg
# Успешно: Pekinese_6956_jpg.rf.bd6b75c754468e7ea0ad02634fc8fea6.jpg
# Успешно: Pekinese_2209_jpg.rf.6abd171bfbc405cd2bf21f77e7ddd24e.jpg
# Успешно: Pekinese_3996_jpg.rf.07271d50098ed822c2d64116c3bc0065.jpg
# Успешно: Pekinese_5087_jpg.rf.6b3e5e83520587c2d5a42e021848ed6a.jpg
# Успешно: Pekinese_7959_jpg.rf.8925bbb231849f647c4f6022298d9d49.jpg
# Успешно: Pekinese_8204_jpg.rf.b1259c4fe1147c9da6895036f1344e1d.jpg
# Успешно: Pekinese_2793_jpg.rf.60d1b4e82842d06f20e9764fe57908d6.jpg
# Успешно: Pekinese_10689_jpg.rf.8c4e1d3daeaf497e73034de6ec54705b.jpg
# Успешно: Pekinese_20360_jpg.rf.ac4a0033b3fb2511fa71c60bdd8839e7.jpg
# Успешно: Pekinese_11684_jpg.rf.356023a5fc0cf9087ec768943f7d0e10.jpg
# Успешно: Pekinese_7959_jpg.rf.0e69584193ae97cbccc277c689eae6be.jpg
# Успешно: Pekinese_12125_jpg.rf.b52ba627dc4838b703ccdca67e2968c3.jpg
# Успешно: Pekinese_15842_jpg.rf.b2eee67ed18af708fea3e9a62c351bca.jpg
# Успешно: Pekinese_1877_jpg.rf.a5418e315f1c6a88d2ae26d0578cf498.jpg
# Успешно: Pekinese_7817_jpg.rf.dda231d2acd2755be6b87d54eb5bf79a.jpg
# Успешно: Pekinese_14307_jpg.rf.05587ab9e5734806684b885e012f8174.jpg
# Успешно: Pekinese_15375_jpg.rf.482098e619256c532bb47a67c798f00a.jpg
# Успешно: Pekinese_8726_jpg.rf.2d447cf494ac75b7bf98fe3d307e8bba.jpg
# Успешно: Pekinese_19690_jpg.rf.845a43234f8cf767aa44da3178255753.jpg
# Успешно: Pekinese_21117_jpg.rf.00f4894377cbd15d376ea16e0fd33260.jpg
# Успешно: Pekinese_14359_jpg.rf.074a372fcff1dfccd30236b28ea3df83.jpg
# Успешно: Pekinese_11684_jpg.rf.a7d966e9473992b2a9bf9365992130e6.jpg
# Успешно: Pekinese_4355_jpg.rf.ea15d9c20630495a91e96724fb0485f5.jpg
# Успешно: Pekinese_10294_jpg.rf.291dc1299514ff800f00381b24a1477a.jpg
# Успешно: Pekinese_4355_jpg.rf.73af9cf8fefa278271113291169b7402.jpg
# Успешно: Pekinese_10721_jpg.rf.c70a59645039c528edcf19b3ee17bc88.jpg
# Успешно: Pekinese_2358_jpg.rf.2304089b06a2c224dcce35743a1c2198.jpg
# Успешно: Pekinese_14307_jpg.rf.e185e712c792da741cba27a2ff7ba8e9.jpg
# Успешно: Pekinese_499_jpg.rf.b649a7c1b08576ac908230bbd7ad4170.jpg
# Успешно: Pekinese_9316_jpg.rf.ca2a0a2f8709616249981aeb2f73a0dc.jpg
# Успешно: Pekinese_9756_jpg.rf.abe0f85c40931e2ec73553b1d0dfc6fe.jpg
# Успешно: Pekinese_1591_jpg.rf.25deb2867acb62c308bbad56b2a449a5.jpg
# Успешно: Pekinese_6180_jpg.rf.3a123ce0e468769bc0708dcd933fe8b1.jpg
# Успешно: Pekinese_17686_jpg.rf.f9bd00b5e52c22de5c22f4f71b0275a6.jpg
# Успешно: Pekinese_4129_jpg.rf.b8de6ab47d4571199e00c2e5b9d0b941.jpg
# Успешно: Pekinese_5106_jpg.rf.21bf15cfb750760f78ecb9a056a7034f.jpg
# Успешно: Pekinese_869_jpg.rf.552ca37818a1518497f2e605dac95dde.jpg
# Успешно: Pekinese_11679_jpg.rf.dbedb4821b206efeaa4d5b3cd6af6627.jpg
# Успешно: Pekinese_11089_jpg.rf.2d210d8a1899d67f20c1963340a0f300.jpg
# Успешно: Pekinese_14748_jpg.rf.e8d138410bf14bd2c8039a60690a210c.jpg
# Успешно: Pekinese_21987_jpg.rf.86fd92e21d3c484ca79cfdd0691c89b0.jpg
# Успешно: Pekinese_11089_jpg.rf.a65248ae3a2ff3fe82243760658003b7.jpg
# Успешно: Pekinese_15842_jpg.rf.8d76282fe642b70e7ec7f6bcd2224bda.jpg
# Успешно: Pekinese_2935_jpg.rf.dd74e24738405c98d47d6ff4c772d8ed.jpg
# Успешно: Pekinese_9151_jpg.rf.e2ea94978aefa7d8bfde0bb44d83a6ee.jpg
# Успешно: Pekinese_15842_jpg.rf.fc1285db13890622e3e61722a9f1e9d4.jpg
# Успешно: Pekinese_10294_jpg.rf.e665433f35b71f3e025b616664e397b0.jpg
# Успешно: Pekinese_4129_jpg.rf.b61f9511983196d5d0ed82dd2e83ed1c.jpg
# Успешно: Pekinese_11420_jpg.rf.1f238513824c559a60419a145f741e26.jpg
# Успешно: Pekinese_2358_jpg.rf.10bc7bb6ff8f393f7baef8bd2af0c705.jpg
# Успешно: Pekinese_207_jpg.rf.c2d14bb167faa3c658140ff8ef848a9a.jpg
# Успешно: Pekinese_19690_jpg.rf.0c4a1ce34b27f674dcd067593c02afab.jpg
# Успешно: Pekinese_186_jpg.rf.ac6800c90699b11ed6f246efde5b3119.jpg
# Успешно: Pekinese_7817_jpg.rf.a3a1b35726188d79e2a3f915bfa117e2.jpg
# Успешно: Pekinese_15220_jpg.rf.395930a35c6b520866b6c52f1abf3ade.jpg
# Успешно: Pekinese_2358_jpg.rf.b66f44e75623aa211d1ed9b62e2a5a26.jpg
# Успешно: Pekinese_11984_jpg.rf.b3c5d8192dc16436bfc9df85dbd1625e.jpg
# Успешно: Pekinese_21103_jpg.rf.c4cdaa8568e063d6eeff0ed66b702cc4.jpg
# Успешно: Pekinese_10951_jpg.rf.db0620761f5de7beea011a59a68556d7.jpg
# Успешно: Pekinese_422_jpg.rf.005eb5cd5282c8bb7d709aaa8afa8481.jpg
# Успешно: Pekinese_14748_jpg.rf.72e88f4ed88c1c42ea9b064d6bc267aa.jpg
# Успешно: Pekinese_21117_jpg.rf.187c911e4a13727f6fbeb46d8bec81e3.jpg
# Успешно: Pekinese_2793_jpg.rf.75900029f3c39ae2dfe5ae94d3d8cc7b.jpg
# Успешно: Pekinese_1451_jpg.rf.a850294f76fec76769f2cf6bd6f7e834.jpg
# Успешно: Pekinese_11420_jpg.rf.0cfa81fb458af0e330c7b60fdde0808d.jpg
# Успешно: Pekinese_6096_jpg.rf.78932edd3497c7e9446394d2b34a889d.jpg
# Успешно: Pekinese_17983_jpg.rf.66214d7976a460fddd8369992dd24c13.jpg
# Успешно: Pekinese_937_jpg.rf.3a2e00564e24690bb6ad2f65a995fa4d.jpg
# Успешно: Pekinese_10294_jpg.rf.8994d0f3f00dd8200608fb909683e363.jpg
# Успешно: Pekinese_13897_jpg.rf.ce82be74b93736db88ab352c9a5e6235.jpg
# Успешно: Pekinese_4412_jpg.rf.7c82638968293c837e24a9a57361490c.jpg
# Успешно: Pekinese_12321_jpg.rf.df9cd529ca3a51509167c02c7c6f3808.jpg
# Успешно: Pekinese_15871_jpg.rf.a9c304329d75c6af7bd9fa32bb3e84b4.jpg
# Успешно: Pekinese_186_jpg.rf.4bc3d04c75b0d151d9057b045347ce05.jpg
# Успешно: Pekinese_1020_jpg.rf.aad8ddd2acebe7c9c05b18bf884ebdb7.jpg
# Успешно: Pekinese_5766_jpg.rf.d8ea5629ff620a1dfadfebe2003e5aa3.jpg
# Успешно: Pekinese_347_jpg.rf.9273119e4176377840f4cfff539c7edd.jpg
# Успешно: Pekinese_13647_jpg.rf.a4d42588c392c9b82d776f0eca0679f5.jpg
# Успешно: Pekinese_422_jpg.rf.67e449e9496be75a38a701abf2c599c6.jpg
# Успешно: Pekinese_13897_jpg.rf.e6a28bb686eff0d41c634db28ae2f04c.jpg
# Успешно: Pekinese_1820_jpg.rf.adf8e708b0360e9010876effc2176472.jpg
# Успешно: Pekinese_8127_jpg.rf.42cd38678e16cf9755d484c7e6004258.jpg
# Успешно: Pekinese_4355_jpg.rf.54f26d568b93379758e9d69c95954fd6.jpg
# Успешно: Pekinese_11420_jpg.rf.8027db927b069d6aee7b5d60cc1fc288.jpg
# Успешно: Pekinese_6467_jpg.rf.1f2382d1fd5402ad48ee1f7e0992f866.jpg
# Обрабатываю batch 3/4
# Успешно: Pekinese_21117_jpg.rf.85ee7bcdcb1f4bd2f18afeb23ab1dd0b.jpg
# Успешно: Pekinese_5522_jpg.rf.dc6bbca86d1942fda77211f9929ef801.jpg
# Успешно: Pekinese_1820_jpg.rf.311bd444916254783891edd79cb7803e.jpg
# Успешно: Pekinese_14748_jpg.rf.0fc31835d538e2b1445cd7d5068c5a2e.jpg
# Успешно: Pekinese_3149_jpg.rf.d95052a94073b7f01a9ba2dd7eac0dec.jpg
# Успешно: Pekinese_16313_jpg.rf.23f50ca5fce54341d8cf221f1fa51abe.jpg
# Успешно: Pekinese_12125_jpg.rf.9423a11bd10e7e1de62102f64e42df41.jpg
# Успешно: Pekinese_8204_jpg.rf.fbe8e11f3a6edbb4242b2d3da8ac4ca7.jpg
# Успешно: Pekinese_11322_jpg.rf.66dd7d5c281798bee38169e552ba7cc5.jpg
# Успешно: Pekinese_4456_jpg.rf.5e6d2a3b4b6f859b2fb60e021ac868d7.jpg
# Успешно: Pekinese_380_jpg.rf.42a69aa53e042616916c1fcf904171fe.jpg
# Успешно: Pekinese_11984_jpg.rf.712ec1034a29a0e6fc7e80a2ef609d3a.jpg
# Успешно: Pekinese_10951_jpg.rf.86071c8c7c2c00eabd74a9768913e89b.jpg
# Успешно: Pekinese_10721_jpg.rf.6bf7f32bd38caab028fe50c337034578.jpg
# Успешно: Pekinese_11089_jpg.rf.4f77ed81430c39e2602efcf1e6d0fd94.jpg
# Успешно: Pekinese_6333_jpg.rf.fa6b1ad6e8772cae8b6ef94588425454.jpg
# Успешно: Pekinese_9756_jpg.rf.d8e840d18f346e67e069ea0691f4e6cd.jpg
# Успешно: Pekinese_4412_jpg.rf.af6d72001ae15a5a4d71280c9ed55cb6.jpg
# Успешно: Pekinese_7068_jpg.rf.a17474b1a86d7e8703f2434b21d2d741.jpg
# Успешно: Pekinese_8826_jpg.rf.9083c287410c9e58f96429c7b45cffb3.jpg
# Успешно: Pekinese_17686_jpg.rf.b3a9aefd22fc93f5bb02aa172be26fa2.jpg
# Успешно: Pekinese_5106_jpg.rf.cab29d20ce62c071651b711bf8a3f257.jpg
# Успешно: Pekinese_9151_jpg.rf.473ca7c977b084353ffe6ed5faab1f79.jpg
# Успешно: Pekinese_21987_jpg.rf.0c4225f1c6c05a6eba9b6f6ef990fd4b.jpg
# Успешно: Pekinese_17103_jpg.rf.516fa4f8b252c8e8da59e080e55e4569.jpg
# Успешно: Pekinese_3996_jpg.rf.ed00a26f2037ecf8fc68ef13fc4c9ca0.jpg
# Успешно: Pekinese_2209_jpg.rf.e662544414efaebbe03cc1f83848e8d6.jpg
# Успешно: Pekinese_17983_jpg.rf.09d1651619c0cadf61620c236623380b.jpg
# Успешно: Pekinese_6620_jpg.rf.8b6f6d90b3982de4138f9658fc776d6d.jpg
# Успешно: Pekinese_20360_jpg.rf.281ab3f65d903d9f06589e9df82699b4.jpg
# Успешно: Pekinese_1877_jpg.rf.249008c39ac27b79a83a2807e8b86df1.jpg
# Успешно: Pekinese_15871_jpg.rf.8cc2314db6e2c2f4da91a29a80830a0b.jpg
# Успешно: Pekinese_5766_jpg.rf.2c957ab6167f029b3c1df1f6adb82b7e.jpg
# Успешно: Pekinese_1820_jpg.rf.38d65843f8ccf3ebfc8092e97a9cab7a.jpg
# Успешно: Pekinese_8127_jpg.rf.1153e96bc49d8fc41d0cc7297af91906.jpg
# Успешно: Pekinese_186_jpg.rf.b4388c3d2f7b1de1c9344cf5761b7c82.jpg
# Успешно: Pekinese_380_jpg.rf.273fa7c1c35e0a15cba1d8fbe49b0a51.jpg
# Успешно: Pekinese_17291_jpg.rf.73abefe2cbe87056c2e1f0c201ecfc72.jpg
# Успешно: Pekinese_15375_jpg.rf.2981ec77e1fe4961b434d599587ad081.jpg
# Успешно: Pekinese_207_jpg.rf.73ea460bc6793b871c1f149c57a79d6d.jpg
# Успешно: Pekinese_11511_jpg.rf.7adc7fc9be4a3dea31ffe1e59de5a8bf.jpg
# Успешно: Pekinese_2368_jpg.rf.30d4f0b8412c1589d275382f867039a7.jpg
# Успешно: Pekinese_16313_jpg.rf.c564f0d189b92b7f6bd3c5d30751bf54.jpg
# Успешно: Pekinese_2073_jpg.rf.e6b2b7b1ccd55bf90c72b1028fbfd1d6.jpg
# Успешно: Pekinese_2935_jpg.rf.731861d44eb92a9cd2d61eca2eca3d2d.jpg
# Успешно: Pekinese_347_jpg.rf.0e4d1add8d7705a45424b2eb60ef3ad4.jpg
# Успешно: Pekinese_16313_jpg.rf.c9b574a1cab7ea4076b93734a02ffe5a.jpg
# Успешно: Pekinese_2793_jpg.rf.9b654e348b53e3d757fa1ac77ac4ffc4.jpg
# Успешно: Pekinese_7959_jpg.rf.e62914ab7c56065a538ef478a741b6fb.jpg
# Успешно: Pekinese_11679_jpg.rf.4aa630d4c1731feed3bce6698f75690b.jpg
# Успешно: Pekinese_22412_jpg.rf.4092b9ce812b497c96bde2661c928924.jpg
# Успешно: Pekinese_6096_jpg.rf.da9fde15094d1093fb63fa944a5d77b3.jpg
# Успешно: Pekinese_21987_jpg.rf.96cb49be7a147fc7926faed4a53a9dba.jpg
# Успешно: Pekinese_422_jpg.rf.4cf1a6eceb034061f7630151a726b6ac.jpg
# Успешно: Pekinese_8726_jpg.rf.716a300fe005c2526cff4ba8c4936be1.jpg
# Успешно: Pekinese_10615_jpg.rf.a821b215aa56bf4321d7f6b5b7754d19.jpg
# Успешно: Pekinese_6243_jpg.rf.cccc1324b08b3f83905a7e2381fd42b4.jpg
# Успешно: Pekinese_22136_jpg.rf.448f772759640a8b6d3fd1524eb78e36.jpg
# Успешно: Pekinese_904_jpg.rf.5f1973166c3411daebf92ffb1f4da48f.jpg
# Успешно: Pekinese_5555_jpg.rf.1382dfba6d168439034cec93eb4c5fab.jpg
# Успешно: Pekinese_14999_jpg.rf.456cfd49f94db222b7e75628bc8cecc1.jpg
# Успешно: Pekinese_18764_jpg.rf.233ffb157c0bcaeb03a9ee972bb4ab39.jpg
# Успешно: Pekinese_10958_jpg.rf.e884feecd709ab265f093b0e75649399.jpg
# Успешно: Pekinese_16367_jpg.rf.b7e2a5c9e372ce56dc6496410a4dc3cb.jpg
# Успешно: Pekinese_16979_jpg.rf.1cfbd2973e8c8cc6ff456f2a6ce029c3.jpg
# Успешно: Pekinese_2933_jpg.rf.638365b706e35dc5bddd63e64002a35b.jpg
# Успешно: Pekinese_3774_jpg.rf.69357709f03e5be33b7de8a0bcdf19dd.jpg
# Успешно: Pekinese_4350_jpg.rf.d744388cae7341f94c303beddb0dcb2f.jpg
# Успешно: Pekinese_13024_jpg.rf.d4c32ce3fb10b7a199af47b9287cfc92.jpg
# Успешно: Pekinese_10603_jpg.rf.3ac69d7538379ad07569efb44877b764.jpg
# Успешно: Pekinese_16268_jpg.rf.28d053c99eeb86b575344049a7ca87eb.jpg
# Успешно: Pekinese_4843_jpg.rf.cf028b16f41cb235399aaca2ae74729d.jpg
# Успешно: Pekinese_14929_jpg.rf.fc57a7860efb26dd717f1ba133af33d2.jpg
# Успешно: Pekinese_17205_jpg.rf.7d390c6fdb0b7e4995a2fe5f2b39f898.jpg
# Успешно: Pekinese_3832_jpg.rf.2b5ce521aafc51315e6f00648d979e76.jpg
# Успешно: Pekinese_17886_jpg.rf.de194514ce6a3681c69b13fe9131f5fb.jpg
# Успешно: Pekinese_146_jpg.rf.67cb3fbf6f567c8bb09d2e9b67947e02.jpg
# Успешно: Pekinese_10627_jpg.rf.d5cbe25005c5004657bf3351605b3fc9.jpg
# Успешно: Pekinese_16693_jpg.rf.46837bf5405665732921d4be96570f89.jpg
# Успешно: Pekinese_7235_jpg.rf.90592ddca05e66e692dc7903d1d82f07.jpg
# Успешно: Pekinese_5197_jpg.rf.a5eab75685d4d5977df3a5352061045e.jpg
# Успешно: Pekinese_15979_jpg.rf.69e5f22f2fdef959be9bdfc3138db126.jpg
# Успешно: Pekinese_17564_jpg.rf.3d032787d78795d2600640f00f02c9fb.jpg
# Успешно: Pekinese_5125_jpg.rf.c5fa730ba9cce62069ced613add5a555.jpg
# Успешно: Pekinese_10613_jpg.rf.4294f6c0d55305e1e707e309c508180b.jpg
# Успешно: Pekinese_20762_jpg.rf.ac165b718343fcf1c90f5411961ebee1.jpg
# Успешно: Pekinese_18899_jpg.rf.1ddf8c7beb406071265da6869f33f501.jpg
# Успешно: Pekinese_10373_jpg.rf.2ddc1deeb363527bd89b723425e0e608.jpg
# Успешно: Pekinese_6712_jpg.rf.84dd3502ce62601a87b5b7027e7bf5e9.jpg
# Успешно: Pekinese_356_jpg.rf.d80ee609763241e8ced16a46bb5e8831.jpg
# Успешно: Pekinese_8902_jpg.rf.ae67e2356ada9300ce18940f87851ccb.jpg
# Успешно: Pekinese_884_jpg.rf.08585a72a3c9d9311d1929aa93692161.jpg
# Успешно: Pekinese_7944_jpg.rf.f43ea9916d6ed3c446eb8cb59fe57f41.jpg
# Успешно: Pekinese_11664_jpg.rf.c2259e6627cf57eb082dca89fe2a53ed.jpg
# Успешно: Pekinese_4984_jpg.rf.73081eb865d219495680a94480ed2a59.jpg
# Успешно: Pekinese_14208_jpg.rf.e250ad93573d9f7dc09608bc65bac0c1.jpg
# Успешно: Pekinese_606_jpg.rf.3d0e2cd8bb22663211d3d4fc91e68ad3.jpg
# Успешно: Pekinese_2766_jpg.rf.1f5aeff08c4506e7dbd691acf667305d.jpg
# Успешно: Pekinese_17015_jpg.rf.4bc1211ce13d2b717ac8d4985d363558.jpg
# Успешно: Pekinese_155_jpg.rf.6551bd7d0c033acc23fecc28bff8dd03.jpg
# Обрабатываю batch 4/4
# Успешно: Pekinese_19863_jpg.rf.8fd54b1f3551fce798b038b769b1a904.jpg
# Успешно: Pekinese_8074_jpg.rf.8c5da48064eeb6377c3aab788056e651.jpg
# Успешно: Pekinese_9408_jpg.rf.adc3b0aa776f54c742f694835677e606.jpg
# Успешно: Pekinese_2893_jpg.rf.8790a0ee838a168d44c742e635bf1684.jpg
# Успешно: Pekinese_3493_jpg.rf.ab5427e6670faacac9098410562d590b.jpg
# Успешно: Pekinese_8229_jpg.rf.c8a3f2244294b4ec1cb255726aecdaab.jpg
# Успешно: Pekinese_8595_jpg.rf.fb78643f42839081793808b80f5026d5.jpg
# Успешно: Pekinese_10059_jpg.rf.9b1982ac7545154a6f1f51ce218282ac.jpg
# Успешно: Pekinese_952_jpg.rf.11df451124d43818f1f8a07e20760d06.jpg
# Успешно: Pekinese_9847_jpg.rf.4355c4436f53bc6ac8ce3d228862e0a3.jpg
# Успешно: Pekinese_10159_jpg.rf.bf849f9bc220479d893e8b57d9671697.jpg
# Успешно: Pekinese_7027_jpg.rf.71b9f724d3a2e9784f2d6da39cdecfdd.jpg
# Успешно: Pekinese_6926_jpg.rf.97aca2daf789b3c9a208ccff79ee47ca.jpg
# Успешно: Pekinese_10600_jpg.rf.14c4d9ecfc51c6ce4c126e1b766bcf79.jpg
# Успешно: Pekinese_7302_jpg.rf.d06d8cca70b6f46393fdf0a14a329ef1.jpg
# Успешно: Pekinese_3402_jpg.rf.17ff5849ff01c80301eb2449ae17e142.jpg
# Успешно: Pekinese_14360_jpg.rf.a72558a9e3ceb9d4fba2aeb600b5d890.jpg
# Успешно: Pekinese_1759_jpg.rf.4e9de6f0c62e24e0a3d0723a42b32804.jpg
# Успешно: Pekinese_7769_jpg.rf.5e14159943e79f19ad4b7b11071386e7.jpg
#
# Обработано 319 изображений

# %%
import json
import numpy as np
import os
from pathlib import Path

def nms(boxes, scores, iou_threshold=0.5):
    """
    Non-Maximum Suppression из numpy
    boxes: [[x1, y1, x2, y2], ...] в абсолютных координатах
    scores: [confidence1, confidence2, ...]
    """
    if len(boxes) == 0:
        return []
    
    boxes = np.array(boxes)
    scores = np.array(scores)
    
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]
    
    areas = (x2 - x1 + 1) * (y2 - y1 + 1)
    order = scores.argsort()[::-1]
    
    keep = []
    while order.size > 0:
        i = order[0]
        keep.append(i)
        
        xx1 = np.maximum(x1[i], x1[order[1:]])
        yy1 = np.maximum(y1[i], y1[order[1:]])
        xx2 = np.minimum(x2[i], x2[order[1:]])
        yy2 = np.minimum(y2[i], y2[order[1:]])
        
        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)
        inter = w * h
        
        iou = inter / (areas[i] + areas[order[1:]] - inter)
        
        inds = np.where(iou <= iou_threshold)[0]
        order = order[inds + 1]
    
    return keep

def convert_to_x1y1x2y2(bbox):
    """Конвертирует [x_center, y_center, width, height] в [x1, y1, x2, y2]"""
    x, y, w, h = bbox
    x1 = x - w/2
    y1 = y - h/2
    x2 = x + w/2
    y2 = y + h/2
    return [x1, y1, x2, y2]

def calculate_centrality(x_center, y_center, img_width, img_height):
    """Вычисляет центральность (0-1, где 1 - центр)"""
    center_x = img_width / 2
    center_y = img_height / 2
    
    # Нормализованное расстояние от центра (0 = центр, 1 = угол)
    distance = np.sqrt(((x_center - center_x) / img_width)**2 + 
                       ((y_center - center_y) / img_height)**2)
    
    # Инвертируем: 1 - центр, 0 - край
    centrality = 1 - (distance * np.sqrt(2))  # sqrt(2) для нормализации
    return max(0, centrality)  # Не ниже 0

def select_best_bbox(predictions, img_width, img_height):
    """Выбирает лучший bounding box"""
    if not predictions:
        return None
    
    # 1. Фильтрация по размеру (7%-90%)
    filtered = []
    for pred in predictions:
        area = (pred['width'] * pred['height']) / (img_width * img_height)
        if 0.07 <= area <= 0.9:
            filtered.append(pred)
    
    # Если все отфильтровались, берем все
    if not filtered:
        filtered = predictions
    
    # Подготовка для NMS
    boxes = []
    scores = []
    bbox_data = []  # Сохраняем оригинальные данные
    
    for pred in filtered:
        bbox = [pred['x'], pred['y'], pred['width'], pred['height']]
        boxes.append(convert_to_x1y1x2y2(bbox))
        scores.append(pred['confidence'])
        bbox_data.append(pred)
    
    # 2. NMS
    if len(boxes) > 1:
        keep_indices = nms(boxes, scores, iou_threshold=0.5)
        filtered = [bbox_data[i] for i in keep_indices]
        boxes = [boxes[i] for i in keep_indices]
        scores = [scores[i] for i in keep_indices]
    
    if not filtered:
        return None
    
    # 3. Сортировка по confidence
    sorted_indices = np.argsort(scores)[::-1]
    filtered = [filtered[i] for i in sorted_indices]
    scores = [scores[i] for i in sorted_indices]
    
    # 4. Проверка центральности
    best_box = filtered[0]
    best_centrality = calculate_centrality(best_box['x'], best_box['y'], 
                                           img_width, img_height)
    
    if best_centrality > 0.3:  # Порог центральности
        return best_box
    
    # 5. Ищем более центральный бокс
    for i, pred in enumerate(filtered):
        centrality = calculate_centrality(pred['x'], pred['y'], 
                                         img_width, img_height)
        if centrality > best_centrality + 0.2:  # Существенно более центральный
            return pred
    
    return best_box  # Возвращаем самый уверенный

def process_json_file(input_file, output_file):
    """Обрабатывает JSON файл с аннотациями"""
    with open(input_file, 'r') as f:
        data = json.load(f)
    
    processed_data = {}
    
    for img_path, content in data.items():
        if 'result' not in content or not content['result']:
            continue
        
        # Получаем информацию об изображении и предсказаниях
        result = content['result'][0]
        if 'predictions' not in result:
            continue
        
        predictions_data = result['predictions']
        img_width = predictions_data.get('image', {}).get('width', 256)
        img_height = predictions_data.get('image', {}).get('height', 256)
        predictions_list = predictions_data.get('predictions', [])
        
        # Выбираем лучший бокс
        best_box = select_best_bbox(predictions_list, img_width, img_height)
        
        # Создаем новую структуру
        if best_box:
            # Оставляем только нужные поля
            clean_box = {
                'x': best_box['x'],
                'y': best_box['y'],
                'width': best_box['width'],
                'height': best_box['height'],
                'confidence': best_box['confidence'],
                'class_id': best_box.get('class_id', 0),
                'class': best_box.get('class', 'dog')
            }
            
            processed_data[img_path] = {
                'result': [{
                    'predictions': {
                        'image': {'width': img_width, 'height': img_height},
                        'predictions': [clean_box]
                    }
                }]
            }
    
    # Сохраняем результат
    with open(output_file, 'w') as f:
        json.dump(processed_data, f, indent=2)
    
    print(f"Обработано: {len(processed_data)} изображений в {output_file}")
    return processed_data

# Обработка всех файлов
files = [
    ("Chihuahua.json", "Chihuahua_processed.json"),
    ("Japanese_spaniel.json", "Japanese_spaniel_processed.json"),
    ("Maltese_dog.json", "Maltese_dog_processed.json"),
    ("Pekinese.json", "Pekinese_processed.json")
]

for input_file, output_file in files:
    if os.path.exists(input_file):
        print(f"\nОбработка {input_file}...")
        process_json_file(input_file, output_file)
    else:
        print(f"Файл не найден: {input_file}")
# Out:
# Обработка Chihuahua.json...
# Обработано: 320 изображений в Chihuahua_processed.json
#
# Обработка Japanese_spaniel.json...
# Обработано: 308 изображений в Japanese_spaniel_processed.json
#
# Обработка Maltese_dog.json...
# Обработано: 571 изображений в Maltese_dog_processed.json
#
# Обработка Pekinese.json...
# Обработано: 288 изображений в Pekinese_processed.json

# %%
import json
import os

def check_annotations_for_missing_boxes(annotation_file):
    """
    Проверяет, какие изображения не имеют bounding box в аннотациях
    """
    with open(annotation_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    images_without_boxes = []
    images_with_boxes = []
    total_count = len(data)
    
    for img_path, content in data.items():
        has_box = False
        
        # Проверяем наличие result
        if "result" in content and content["result"]:
            for result_item in content["result"]:
                # Проверяем наличие predictions
                if "predictions" in result_item:
                    predictions_data = result_item["predictions"]
                    
                    # Проверяем наличие списка predictions внутри predictions
                    if ("predictions" in predictions_data and 
                        isinstance(predictions_data["predictions"], list) and 
                        len(predictions_data["predictions"]) > 0):
                        
                        # Проверяем, есть ли хоть один валидный бокс
                        for pred in predictions_data["predictions"]:
                            if all(key in pred for key in ["x", "y", "width", "height"]):
                                has_box = True
                                break
        
        if has_box:
            images_with_boxes.append(img_path)
        else:
            images_without_boxes.append(img_path)
    
    return {
        "total": total_count,
        "with_boxes": len(images_with_boxes),
        "without_boxes": len(images_without_boxes),
        "percentage_with_boxes": (len(images_with_boxes) / total_count * 100) if total_count > 0 else 0,
        "images_without_boxes": images_without_boxes,
        "images_with_boxes": images_with_boxes
    }

def analyze_all_annotation_files(files):
    """
    Анализирует все файлы аннотаций и выводит сводку
    """
    results = {}
    
    for file in files:
        if os.path.exists(file):
            print(f"\n{'='*60}")
            print(f"Анализ файла: {file}")
            print('='*60)
            
            result = check_annotations_for_missing_boxes(file)
            results[file] = result
            
            print(f"Всего изображений: {result['total']}")
            print(f"С боксами: {result['with_boxes']}")
            print(f"Без боксов: {result['without_boxes']}")
            print(f"Процент с боксами: {result['percentage_with_boxes']:.1f}%")
            
            if result['without_boxes'] > 0:
                print(f"\nИзображения без боксов ({len(result['images_without_boxes'])}):")
                for i, img_path in enumerate(result['images_without_boxes'][:10]):  # Показываем первые 10
                    print(f"  {i+1}. {os.path.basename(img_path)}")
                if len(result['images_without_boxes']) > 10:
                    print(f"  ... и еще {len(result['images_without_boxes']) - 10} изображений")
        else:
            print(f"\nФайл не найден: {file}")
    
    return results

def generate_summary_report(results):
    """
    Генерирует сводный отчет по всем файлам
    """
    print(f"\n{'='*60}")
    print("СВОДНЫЙ ОТЧЕТ")
    print('='*60)
    
    total_all_images = 0
    total_with_boxes = 0
    total_without_boxes = 0
    
    for file_name, data in results.items():
        total_all_images += data['total']
        total_with_boxes += data['with_boxes']
        total_without_boxes += data['without_boxes']
        
        print(f"\n{os.path.basename(file_name)}:")
        print(f"  Изображений с боксами: {data['with_boxes']}/{data['total']} ({data['percentage_with_boxes']:.1f}%)")
    
    if total_all_images > 0:
        percentage_total = (total_with_boxes / total_all_images) * 100
        print(f"\n{'='*40}")
        print(f"ИТОГО по всем файлам:")
        print(f"  Всего изображений: {total_all_images}")
        print(f"  С боксами: {total_with_boxes} ({percentage_total:.1f}%)")
        print(f"  Без боксов: {total_without_boxes} ({100 - percentage_total:.1f}%)")
    
    # Сохраняем отчет в файл
    with open("annotation_report.txt", "w", encoding='utf-8') as f:
        f.write("ОТЧЕТ ПО АННОТАЦИЯМ\n")
        f.write("="*50 + "\n\n")
        
        for file_name, data in results.items():
            f.write(f"Файл: {os.path.basename(file_name)}\n")
            f.write(f"  Всего изображений: {data['total']}\n")
            f.write(f"  С боксами: {data['with_boxes']} ({data['percentage_with_boxes']:.1f}%)\n")
            f.write(f"  Без боксов: {data['without_boxes']}\n")
            
            if data['without_boxes'] > 0:
                f.write("\n  Изображения без боксов:\n")
                for img_path in data['images_without_boxes']:
                    f.write(f"    - {os.path.basename(img_path)}\n")
            f.write("\n")
        
        if total_all_images > 0:
            f.write("="*50 + "\n")
            f.write(f"ИТОГО:\n")
            f.write(f"  Всего изображений: {total_all_images}\n")
            f.write(f"  С боксами: {total_with_boxes} ({(total_with_boxes/total_all_images*100):.1f}%)\n")
            f.write(f"  Без боксов: {total_without_boxes}\n")
    
    print(f"\nПолный отчет сохранен в: annotation_report.txt")

# Список файлов для проверки
annotation_files = [
    "Chihuahua.json",
    "Japanese_spaniel.json", 
    "Maltese_dog.json",
    "Pekinese.json"
]

# Проверяем наличие альтернативных имен файлов
alternative_files = [
    "chihuahua_annotations.json",
    "japanese_spaniel_annotations.json",
    "maltese_annotations.json", 
    "pekinese_annotations.json"
]

# Сначала проверяем основные имена, если нет - альтернативные
files_to_check = []
for main_file, alt_file in zip(annotation_files, alternative_files):
    if os.path.exists(main_file):
        files_to_check.append(main_file)
    elif os.path.exists(alt_file):
        files_to_check.append(alt_file)
        print(f"Используется альтернативное имя: {alt_file}")
    else:
        print(f"Не найден ни один из файлов: {main_file} или {alt_file}")

if files_to_check:
    # Анализируем все файлы
    results = analyze_all_annotation_files(files_to_check)
    
    # Генерируем сводный отчет
    generate_summary_report(results)
    
    # Дополнительная проверка: найти дубликаты между файлами
    print(f"\n{'='*60}")
    print("ПРОВЕРКА НА ДУБЛИКАТЫ МЕЖДУ ФАЙЛАМИ")
    print('='*60)
    
    all_image_paths = []
    for file_name, data in results.items():
        all_image_paths.extend(data['images_with_boxes'])
        all_image_paths.extend(data['images_without_boxes'])
    
    from collections import Counter
    duplicates = {k: v for k, v in Counter(all_image_paths).items() if v > 1}
    
    if duplicates:
        print(f"Найдено дубликатов: {len(duplicates)}")
        for img_path, count in list(duplicates.items())[:5]:
            print(f"  {img_path}: встречается {count} раз(а)")
    else:
        print("Дубликатов не найдено")
else:
    print("Нет файлов для анализа. Проверьте наличие аннотационных файлов.")
# Out:
# ============================================================
# Анализ файла: Chihuahua.json
# ============================================================
# Всего изображений: 323
# С боксами: 320
# Без боксов: 3
# Процент с боксами: 99.1%
#
# Изображения без боксов (3):
#   1. Chihuahua_575_jpg.rf.797af49490645a79b36b1c8f62d62938.jpg
#   2. Chihuahua_3651_jpg.rf.93ea2b458518b72d3308d72e87cc2f64.jpg
#   3. Chihuahua_13383_jpg.rf.58bac7adbf2c934cd62d619a389b386f.jpg
#
# ============================================================
# Анализ файла: Japanese_spaniel.json
# ============================================================
# Всего изображений: 397
# С боксами: 308
# Без боксов: 89
# Процент с боксами: 77.6%
#
# Изображения без боксов (89):
#   1. Japanese_spaniel_3720_jpg.rf.fbe5fd8f396202bdbae52b6bb6144034.jpg
#   2. Japanese_spaniel_3052_jpg.rf.5e577aba9e96cdecfd26ceebcf95d8c1.jpg
#   3. Japanese_spaniel_1890_jpg.rf.588f94d0ecb1471d0018f7952f12918e.jpg
#   4. Japanese_spaniel_3781_jpg.rf.df91c4b565aa27fb047ef7d65c81c916.jpg
#   5. Japanese_spaniel_2886_jpg.rf.602e7f3fb33c30e519fbd771395451d1.jpg
#   6. Japanese_spaniel_4511_jpg.rf.a3b7a407e06491b3124d8c13c4321fd9.jpg
#   7. Japanese_spaniel_1724_jpg.rf.90e8491d8ff20f26aaf9ff7b76e9a3c1.jpg
#   8. Japanese_spaniel_2162_jpg.rf.076f1fe63cb80b7468f6fb1aa30c3ef4.jpg
#   9. Japanese_spaniel_230_jpg.rf.a6de719797a820d7891da50847946525.jpg
#   10. Japanese_spaniel_2250_jpg.rf.de973f615af2082b9efa69a91d5f13fd.jpg
#   ... и еще 79 изображений
#
# ============================================================
# Анализ файла: Maltese_dog.json
# ============================================================
# Всего изображений: 572
# С боксами: 571
# Без боксов: 1
# Процент с боксами: 99.8%
#
# Изображения без боксов (1):
#   1. Maltese_dog_4695_jpg.rf.04bdc128d7a04bce86e12d9984cf2ef9.jpg
#
# ============================================================
# Анализ файла: Pekinese.json
# ============================================================
# Всего изображений: 319
# С боксами: 288
# Без боксов: 31
# Процент с боксами: 90.3%
#
# Изображения без боксов (31):
#   1. Pekinese_10932_jpg.rf.9470714a598215e6825942bcf828922d.jpg
#   2. Pekinese_23100_jpg.rf.964c142e0bc700e41053eb282749639e.jpg
#   3. Pekinese_22412_jpg.rf.28beab8ec56d36447aaee9e64b5c5e39.jpg
#   4. Pekinese_10932_jpg.rf.d12729f698e0ca54d43edeb35bfbd28b.jpg
#   5. Pekinese_22412_jpg.rf.fd5e04440fa4d0b9fb0e9324beb7ac0a.jpg
#   6. Pekinese_8127_jpg.rf.d4872c441f7fcb5b47befa1e5aae47fe.jpg
#   7. Pekinese_869_jpg.rf.3002a86bdc5408d67fc6d5b88f9e94ac.jpg
#   8. Pekinese_2209_jpg.rf.57d166963153dab2e5bffbe296511fb9.jpg
#   9. Pekinese_15842_jpg.rf.b2eee67ed18af708fea3e9a62c351bca.jpg
#   10. Pekinese_15842_jpg.rf.8d76282fe642b70e7ec7f6bcd2224bda.jpg
#   ... и еще 21 изображений
#
# ============================================================
# СВОДНЫЙ ОТЧЕТ
# ============================================================
#
# Chihuahua.json:
#   Изображений с боксами: 320/323 (99.1%)
#
# Japanese_spaniel.json:
#   Изображений с боксами: 308/397 (77.6%)
#
# Maltese_dog.json:
#   Изображений с боксами: 571/572 (99.8%)
#
# Pekinese.json:
#   Изображений с боксами: 288/319 (90.3%)
#
# ========================================
# ИТОГО по всем файлам:
#   Всего изображений: 1611
#   С боксами: 1487 (92.3%)
#   Без боксов: 124 (7.7%)
#
# Полный отчет сохранен в: annotation_report.txt
#
# ============================================================
# ПРОВЕРКА НА ДУБЛИКАТЫ МЕЖДУ ФАЙЛАМИ
# ============================================================
# Дубликатов не найдено

# %%
import json
import os
import glob
from pathlib import Path

# Маппинг пород к классам
BREED_TO_CLASS = {
    "Chihuahua": 0,
    "Japanese_spaniel": 1,
    "Maltese_dog": 2,
    "Pekinese": 3
}

def convert_json_to_yolo(json_file, base_dir="."):
    """
    Конвертирует JSON аннотации в формат YOLO (.txt файлы)
    """
    breed_name = Path(json_file).stem.replace("_processed", "")
    
    if breed_name not in BREED_TO_CLASS:
        print(f"Неизвестная порода: {breed_name}")
        return
    
    class_id = BREED_TO_CLASS[breed_name]
    
    # Загружаем JSON файл
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    processed_count = 0
    missing_count = 0
    
    for img_path, content in data.items():
        # Получаем информацию об изображении
        if "result" not in content or not content["result"]:
            missing_count += 1
            continue
        
        result_item = content["result"][0]
        if "predictions" not in result_item:
            missing_count += 1
            continue
        
        predictions = result_item["predictions"]
        image_info = predictions.get("image", {})
        bbox_list = predictions.get("predictions", [])
        
        if not bbox_list:
            missing_count += 1
            continue
        
        # Берем первый бокс (самый лучший после фильтрации)
        bbox = bbox_list[0]
        
        # Получаем путь к изображению из JSON ключа
        # JSON ключ выглядит как: "./train/Chihuahua/Chihuahua_1271_jpg.rf.cb99fc6d7368e8530b0fa0b76100bc8e.jpg"
        # Нужно извлечь split (train/valid/test), breed и имя файла
        parts = img_path.strip("./").split("/")
        if len(parts) < 3:
            print(f"Некорректный путь: {img_path}")
            continue
        
        split = parts[0]  # train, valid или test
        breed = parts[1]  # порода (должна совпадать с breed_name)
        filename = parts[2]
        
        # Проверяем, существует ли изображение в новой структуре
        # Ищем изображение в папке images
        image_dir = os.path.join(base_dir, split, breed, "images")
        image_path = os.path.join(image_dir, filename)
        
        if not os.path.exists(image_path):
            # Пробуем найти файл с другим расширением
            found = False
            for ext in ['.jpg', '.jpeg', '.png', '.bmp']:
                alt_path = os.path.join(image_dir, os.path.splitext(filename)[0] + ext)
                if os.path.exists(alt_path):
                    image_path = alt_path
                    filename = os.path.basename(alt_path)
                    found = True
                    break
            
            if not found:
                missing_count += 1
                continue
        
        # Получаем размеры изображения
        img_width = image_info.get("width", 256)
        img_height = image_info.get("height", 256)
        
        # Координаты бокса
        x_center = bbox.get("x", 0)
        y_center = bbox.get("y", 0)
        width = bbox.get("width", 0)
        height = bbox.get("height", 0)
        
        # Нормализуем координаты (0-1)
        x_norm = x_center / img_width
        y_norm = y_center / img_height
        w_norm = width / img_width
        h_norm = height / img_height
        
        # Создаем строку для YOLO формата
        yolo_line = f"{class_id} {x_norm:.6f} {y_norm:.6f} {w_norm:.6f} {h_norm:.6f}"
        
        # Создаем путь к файлу аннотаций
        label_dir = os.path.join(base_dir, split, breed, "labels")
        label_filename = os.path.splitext(filename)[0] + ".txt"
        label_path = os.path.join(label_dir, label_filename)
        
        # Записываем аннотацию
        os.makedirs(label_dir, exist_ok=True)
        with open(label_path, 'w', encoding='utf-8') as f:
            f.write(yolo_line)
        
        processed_count += 1
    
    print(f"Обработано {breed_name}: {processed_count} аннотаций, пропущено: {missing_count}")

def process_all_json_files():
    """
    Обрабатывает все обработанные JSON файлы
    """
    json_files = [
        "Chihuahua_processed.json",
        "Japanese_spaniel_processed.json",
        "Maltese_dog_processed.json",
        "Pekinese_processed.json"
    ]
    
    for json_file in json_files:
        if os.path.exists(json_file):
            print(f"\nКонвертация {json_file}...")
            convert_json_to_yolo(json_file)
        else:
            print(f"Файл не найден: {json_file}")

def check_labels_structure():
    """
    Проверяет структуру папок labels и подсчитывает аннотации
    """
    splits = ['train', 'valid', 'test']
    breeds = ['Chihuahua', 'Japanese_spaniel', 'Maltese_dog', 'Pekinese']
    
    print("\nПроверка структуры аннотаций:")
    print("-" * 50)
    
    for split in splits:
        for breed in breeds:
            labels_dir = os.path.join(split, breed, "labels")
            images_dir = os.path.join(split, breed, "images")
            
            if os.path.exists(labels_dir):
                label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
                image_files = [f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))] if os.path.exists(images_dir) else []
                
                print(f"{split}/{breed}:")
                print(f"  Аннотации: {len(label_files)} файлов")
                print(f"  Изображения: {len(image_files)} файлов")
                
                # Проверяем соответствие имен
                if label_files and image_files:
                    missing_labels = []
                    for img_file in image_files:
                        label_file = os.path.splitext(img_file)[0] + ".txt"
                        if label_file not in label_files:
                            missing_labels.append(img_file)
                    
                    if missing_labels:
                        print(f"  Отсутствуют аннотации для {len(missing_labels)} изображений")

def create_yaml_config():
    """
    Создает YAML конфиг для YOLO
    """
    yaml_content = """# YOLO dataset configuration
path: .  # dataset root dir

# Train/val/test splits
train: train  # training images (relative to 'path')
val: valid    # validation images (relative to 'path')
test: test    # test images (relative to 'path')

# Classes
names:
  0: Chihuahua
  1: Japanese_spaniel
  2: Maltese_dog
  3: Pekinese

nc: 4  # number of classes
"""
    
    with open("dataset.yaml", "w", encoding="utf-8") as f:
        f.write(yaml_content)
    
    print("\nСоздан файл конфигурации: dataset.yaml")

if __name__ == "__main__":
    print("Конвертация JSON аннотаций в формат YOLO...")
    print("=" * 60)
    
    # Конвертируем JSON файлы в YOLO формат
    process_all_json_files()
    
    # Проверяем структуру
    check_labels_structure()
    
    # Создаем YAML конфиг
    create_yaml_config()
    
    print("\n" + "=" * 60)
    print("Конвертация завершена!")
    print("Для тренировки YOLO используйте файл: dataset.yaml")
# Out:
# Конвертация JSON аннотаций в формат YOLO...
# ============================================================
#
# Конвертация Chihuahua_processed.json...
# Обработано Chihuahua: 320 аннотаций, пропущено: 0
#
# Конвертация Japanese_spaniel_processed.json...
# Обработано Japanese_spaniel: 308 аннотаций, пропущено: 0
#
# Конвертация Maltese_dog_processed.json...
# Обработано Maltese_dog: 571 аннотаций, пропущено: 0
#
# Конвертация Pekinese_processed.json...
# Обработано Pekinese: 288 аннотаций, пропущено: 0
#
# Проверка структуры аннотаций:
# --------------------------------------------------
# train/Chihuahua:
#   Аннотации: 252 файлов
#   Изображения: 252 файлов
# train/Japanese_spaniel:
#   Аннотации: 274 файлов
#   Изображения: 274 файлов
# train/Maltese_dog:
#   Аннотации: 479 файлов
#   Изображения: 479 файлов
# train/Pekinese:
#   Аннотации: 242 файлов
#   Изображения: 242 файлов
# valid/Chihuahua:
#   Аннотации: 27 файлов
#   Изображения: 27 файлов
# valid/Japanese_spaniel:
#   Аннотации: 43 файлов
#   Изображения: 43 файлов
# valid/Maltese_dog:
#   Аннотации: 46 файлов
#   Изображения: 46 файлов
# valid/Pekinese:
#   Аннотации: 35 файлов
#   Изображения: 35 файлов
# test/Chihuahua:
#   Аннотации: 42 файлов
#   Изображения: 42 файлов
# test/Japanese_spaniel:
#   Аннотации: 35 файлов
#   Изображения: 35 файлов
# test/Maltese_dog:
#   Аннотации: 46 файлов
#   Изображения: 46 файлов
# test/Pekinese:
#   Аннотации: 29 файлов
#   Изображения: 29 файлов
#
# Создан файл конфигурации: dataset.yaml
#
# ============================================================
# Конвертация завершена!
# Для тренировки YOLO используйте файл: dataset.yaml

# %%
import os
from pathlib import Path

dataset_path = Path(".")
for split in ['train', 'valid', 'test']:
    for class_dir in (dataset_path / split).iterdir():
        img_dir = class_dir / 'images'
        lbl_dir = class_dir / 'labels'
        imgs = set(f.stem for f in img_dir.glob('*.jpg'))
        lbls = set(f.stem for f in lbl_dir.glob('*.txt'))
        missing = imgs - lbls
        if missing:
            print(f"ВНИМАНИЕ: В {class_dir} отсутствуют аннотации для {len(missing)} изображений.")
